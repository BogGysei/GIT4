# %% [markdown]
#                             Міністерство освіти і науки, молоді та спорту України
#                                  Західноукраїнський національний університет
#                                Факультет комп'ютерних інформаційних технологій
#
#
#
#                                                                                 Кафедра ІОСУ
#
#
#
#
#                                            Лабораторна робота №3.1
#                                    З дисципліни "Основи Комп'ютерних наук"
#
#
#                                                                                 Виконав
#                                                                                 студент групи КНШІ-11
#                                                                                 Гарболінський Владислав
#
#
#
#                                                 Тернопіль 2023

# %%
import random

def game():
    options = ["rock", "paper", "scissors"]

    while True:
        computer_choice = random.choice(options)
        player_choice = input("Виберіть rock,paper or scissors : ").lower()
+9
        if player_choice not in options:
            print("Неправильно вибрано. Спробуй ще раз")
            continue

        print(f"Твій вибір: {player_choice}")
        print(f"Вибір комп'ютера {computer_choice}")

        if player_choice == computer_choice:
            print("Нічия!")
        elif (player_choice == "rock" and computer_choice == "scissors") or (player_choice == "scissors" and computer_choice == "paper") or (player_choice == "paper" and computer_choice == "rock"):
            print("ТИ ПЕРЕМІГ")
            break
        else:
            print("Комп'ютер переміг")


if __name__ == "__main__":
    game()
# Out:
#   File "<ipython-input-6-57fb0839db14>", line 10
#     if player_choice not in options:
#     ^
# IndentationError: unexpected indent

# %%
# !mkdir /КНШІ-11

# %%
# !mkdir /КНШІ-11/Домашня_робота

# %%
# !touch /КНШІ-11/Домашня_робота/ЛР№3.txt

# %%
# !rm -rf /КНШІ-11

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y = x**2

plt.plot(x, y, label='Парабола: $y=x^2$')

plt.xlabel('Значення x')
plt.ylabel('Значення y')
plt.title('Графік параболи')

plt.legend()

plt.show()

# %% [markdown]
# ![photo1699384557.jpeg](data:image/jpeg;base64,...)
